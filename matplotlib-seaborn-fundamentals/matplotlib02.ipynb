# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
npd1 = np.linspace(0,10,20)
npd2 = npd1 ** 2

# %%
(benimf,benime) = pyt.subplots()
benime.plot(npd1,npd2,color="#3A95AB")
benime.plot(npd2,npd1,color="g")
#aynı zamanda renklendirmeler de color parametresiyle renk kodlarıyla da verilebilir.

# %%
#linewitdh ile çizgi kalınlığı değiştirilebilir.(1.0)
#linestyle ile çizgi stili değiştirilebilir.('--')
#marker,markersize,markerfacecolor çizgilerin içini daha da detaylı kotnrol edebiliriz.

# %%
#scatter

# %%
plt.scatter(npd1,npd2)

# %%
#histogram

# %%
npd3 = np.random.randint(0,100,50)

# %%
plt.hist(npd3)
# Out:
# (array([ 5.,  8.,  4.,  2.,  2.,  6., 12.,  4.,  5.,  2.]),
#  array([ 3. , 12.1, 21.2, 30.3, 39.4, 48.5, 57.6, 66.7, 75.8, 84.9, 94. ]),
#  <BarContainer object of 10 artists>)

# %%
#boxplot

# %%
plt.boxplot(npd3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f49bab3620>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f49bab38c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f49bab34d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f49bab3b60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f49bab3cb0>],
#  'means': []}

# %%
#matplotlib
